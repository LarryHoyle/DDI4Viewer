# %% [markdown]
# # A Network Visualizer for the DDI4 Model
# Larry Hoyle, Institute for Policy and Social Research, University of Kansas
#
# ```YAML
# # fill in the spaces following the ":"s and before the "#" below
# # Copy and paste the whole section below for additional contributors
# # do not change the indentation or the keywords (words preceding a : )
# Title: A Network Visualizer for the DDI4 Model
# Version: 0.02
# Creator:
#   - BibliographicName: Hoyle, Larry  # Contributor name <familyname>, <givenName>
#     Affiliation: IPSR, University of Kansas        # name of the person's organization
#     PersonIDS:
#       - IDValue: http://orcid.org/0000-0002-8262-2393        # identifier for the person
#         IDType: ORCID         # identifier type, e.g. ORCID, ResearcherID
# # You can add additional
# # IDValue,IDtype  pairs lines as needed
#       - IDValue:
#         IDType:
#     Roles:
#       - Role: Conceptualization
#         Extent:  Lead               # leave blank or enter one -  Lead, Equal, Supporting
#       - Role: Data curation
#         Extent:                            # ditto
#       - Role: Formal analysis
#         Extent:                            # ditto
#       - Role: Funding acquisition
#         Extent:                            # ditto
#       - Role: Investigation
#         Extent:                            # ditto
#       - Role: Methodology
#         Extent:  Lead                          # ditto
#       - Role: Project administration
#         Extent:                            # ditto
#       - Role: Resources
#         Extent:                            # ditto
#       - Role: Software
#         Extent:  Lead                          # ditto
#       - Role: Supervision
#         Extent:                            # ditto
#       - Role: Validation
#         Extent:                            # ditto
#       - Role: Visualization
#         Extent:  Lead                          # ditto
#       - Role: Writing – original draft
#         Extent:                            # ditto
#       - Role: Writing – review and editing
#         Extent:                            #  ditto
# ```

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May 10 15:28:25 2016
Revised 2016-05-17
Revised 2016-05-18 - fixed handling of missing cardinalities in relation source

@author: lhoyle
"""

import requests
import re
import xml.etree.ElementTree as ET
import networkx as nx
import matplotlib.pyplot as plt
from networkx_viewer import Viewer

# get the most recent xmi.xml file of the PlatformIndependent DDI4 model
#     from the DDI development website
res = requests.get('http://lion.ddialliance.org/xmi.xml')
res.status_code == requests.codes.ok
print('Processing the following version of the DDI4 xmi.xml Platform Independent Model:')
print(res.text[:167])

# parse the root element of the XML file into an XML tree
rootDDI4XMI = ET.fromstring(res.text)
# print(rootDDI4XMI.tag)

# for each view get a list of its classes
#  make a dictionary of those lists keyed on the view name

diagrams = {}

for diagram in rootDDI4XMI.iter('diagram'): 
    view = diagram.find('model').attrib.get('package')
    if view != 'ComplexDataTypes':
        #print(view)
        classList = []
        for element in diagram.find('elements'):
            classList.append(element.attrib.get('subject'))
        #print('   '+str(classList))
        diagrams[view] = classList
#print(str(diagrams))

def viewList(className, diagrams ):
# given a class name return a list of the Views in which it appears     
    viewList = []
    for viewName, viewClassList in diagrams.items():        
        if className in viewClassList:
            viewList.append(viewName)
    if len(viewList)>0:
        return viewList
    else:
        return        
def cardinalityString(lowerValue, upperValue):
# Given the lower and upper values from an xmi file, return one string e.g. "0..n"
    if lowerValue == None:
        lowerValue = "0"
    elif lowerValue == "-1":
        lowerValue = "n"
    if upperValue == None:
        upperValue = "0"
    elif upperValue == "-1":
        upperValue = "n" 
    return lowerValue + ".." + upperValue  

# create an overall model graph
overallGraph = nx.DiGraph()

# this dictionary will contain a list of properties for each class with properties
classProperties = {}

# this dictionary will contain a list of relations for each class with relations
classRelations = {}

# this dictionary will contain true (is abstract) or false (is not abstract)  for all classes 
classIsAbstract = {}

#this dictionary will contain the parent class name for any class that extends its parent
classParentName = {}

# this dictionary will contain the target cardinality keyed on the relation (association) name
associationTargetCardinality = {}



# populate the classIsAbstract dictionary , create a node in the graph
for packagedElement in rootDDI4XMI.iter('packagedElement'):
    # only want xmi:type="uml:Class"
    if packagedElement.attrib.get('{http://www.omg.org/spec/XMI/20110701}type') == "uml:Class":
        name = packagedElement.attrib.get('name')
        if packagedElement.attrib.get('isAbstract') == 'true':
            classIsAbstract[name] = True
        else:
            classIsAbstract[name] = False
        overallGraph.add_node(name,{'isAbstract':classIsAbstract[name]} )     
    
# populate classParentName with the classes that extend another
for generalization in rootDDI4XMI.iter('generalization'):
    xmiId = generalization.attrib.get('{http://www.omg.org/spec/XMI/20110701}id')
    xmiIdRegex = re.compile(r'''(
           ^([^_]+)_   # child class
           ([^_]+)_    # "extends"
           ([^_]*)$    # parent class
           )''', re.VERBOSE)
    xmiIdSearch = xmiIdRegex.search(xmiId)
    child=xmiIdSearch.group(2)
    parent=xmiIdSearch.group(4)
    classParentName[child] = parent
    overallGraph.add_node(child,{'isAbstract':classIsAbstract[name], 'extends':parent} )
    
    
#populate tne associationTargetCardinality dictionary
for ownedEnd in rootDDI4XMI.iter('ownedEnd'):
    association = ownedEnd.attrib.get('association')
    
    if ownedEnd.find('lowerValue') == None or ownedEnd.find('upperValue') == None:
        targetCardinality = "Missing"
        print("NOTE: missing target cardinality for " + association)
    else:    
        targetCardinality = cardinalityString(ownedEnd.find('lowerValue').attrib.get('value'),ownedEnd.find('upperValue').attrib.get('value'))
    
        
    associationTargetCardinality[association] = targetCardinality
    
# find the Source, Target and relationship name for each relationship in the DDI4 model

for ownedAttribute in rootDDI4XMI.iter('ownedAttribute'):
    association = ownedAttribute.attrib.get('association')
    # NOTE: assumption - Relations all have an association attribute
    if association !=  None:
        associationRegex = re.compile(r'''(
           ^([^_]+)_   # source class
           ([^_]+)_    # association name
           ([^_]*)$    # "association"
           )''', re.VERBOSE)
        oASearch = associationRegex.search(association)
        relationName = oASearch.group(3)
        relationSource = ownedAttribute.attrib.get('name')
        
        relationTarget = ownedAttribute.find('type').attrib.get('{http://www.omg.org/spec/XMI/20110701}idref')
        
        #  extract and edit cardinalities into one string
        
        if ownedAttribute.find('lowerValue') == None:
            lowerCardinalityValue = "Missing"
            print("NOTE: for" + relationSource + "relation " + relationName + "cardinality is missing")                 
        else:
            lowerCardinalityValue = ownedAttribute.find('lowerValue').attrib.get('value')
        
        if ownedAttribute.find('upperValue') == None:
            upperCardinalityValue = "Missing"
            print("NOTE: for" + relationSource + "relation " + relationName + "cardinality is missing")                 
        else:
            upperCardinalityValue = ownedAttribute.find('upperValue').attrib.get('value')   
            
        sourceCardinality = cardinalityString(lowerCardinalityValue, upperCardinalityValue)
        targetCardinality = associationTargetCardinality[association]
        relationCardinality = sourceCardinality + "->" + targetCardinality

        # print(relationSource, relationName, relationTarget)
        
        # put relationNames in a list for each class
        if relationSource in classRelations.keys():
            # add a relation to this class's list
            classRelations[relationSource].append(relationName)
        else:
            classRelations[relationSource] = [relationName]
            
        # add nodes and edge to the graph
        overallGraph.add_node(relationSource,{'properties':classProperties.get(relationSource), 'relations':classRelations.get(relationSource), 'inViews':viewList(relationSource,diagrams),'isAbstract':classIsAbstract[relationSource], 'extends':classParentName.get(relationSource)} )    
        
        #print(relationSource, relationName, relationCardinality)
        overallGraph.add_edge(relationSource, relationTarget, name=relationName, cardinality=relationCardinality)
    else:
        # put properties into a list for each class in a dictionary
        xmiId = ownedAttribute.attrib.get('{http://www.omg.org/spec/XMI/20110701}id')
        idRegex = re.compile(r'''(
             ^([^_]+)_   # class name
             ([^_]*)$    # property
        )''', re.VERBOSE)
        idSearch = idRegex.search(xmiId)
        className = idSearch.group(2)
        propertyName = idSearch.group(3)
        #  extract and edit cardinalities into one string
        propertyCardinality = cardinalityString(ownedAttribute.find('lowerValue').attrib.get('value'),ownedAttribute.find('upperValue').attrib.get('value'))     
        
        if className in classProperties.keys():
            # add a property to this class's list
            classProperties[className].append(propertyName+"("+propertyCardinality+")")
        else:
            classProperties[className] = [propertyName+"("+propertyCardinality+")"]
        overallGraph.add_node(className,{'properties':classProperties.get(className), 'relations':classRelations.get(className), 'inViews':viewList(className,diagrams),'isAbstract':classIsAbstract[className], 'extends':classParentName.get(className)} )    



posSpring =  nx.spring_layout(overallGraph) 
posShell = nx.shell_layout(overallGraph) 

# Reports and Graphs for each View
for viewName, classList in diagrams.items():
    print("\n\nView " + viewName)
    viewPropertyList = []
    for className in classList:
        classPropertyList = classProperties.get(className)
        if classPropertyList != None:
            for propertyName in classPropertyList:
                viewPropertyList.append(propertyName + "(" + className + ")"  )
    viewPropertyList.sort()
    print("\nProperty List")
    for propertyName in viewPropertyList:
        print(propertyName)
    
    # draw a static diagram of each view both as spring-form and circular
    viewGraph = overallGraph.subgraph(classList).copy()
    #print("View: "+viewName)
    print("\nNodes: " + str(viewGraph.nodes()))
    print("\nEdges: " + str(viewGraph.edges()))
    graphLabel = viewName + "_Springform_Layout"
    nx.draw_spring(viewGraph, with_labels=True, node_size=600, node_color='#eeffff', font_size=9) 
    plt.suptitle(graphLabel)
    plt.savefig(viewName + "_spring.png")
    plt.show()
    graphLabel = viewName + "_Circular_Layout"
    nx.draw_circular(viewGraph, with_labels=True, node_size=600, node_color='#eeffff', font_size=9) 
    plt.suptitle(graphLabel)
    plt.savefig(viewName + "_circular.png")
    plt.show()

  
# use the interactive viewer to visualize the graph of the whole model     
app = Viewer(overallGraph)
app.mainloop()
# Out:
# Processing the following version of the DDI4 xmi.xml Platform Independent Model:
# <?xml version="1.0" encoding="UTF-8"?>
# <xmi:XMI xmi:version="2.4.1" xmlns:uml="http://www.omg.org/spec/UML/20110701" xmlns:xmi="http://www.omg.org/spec/XMI/20110701">
# NOTE: missing target cardinality for UnorderedIntervalPair_maps_association
# NOTE: missing target cardinality for UnorderedPair_maps_association
#
#
# View DiscoveryView
#
# Property List
# abstract(0..1)(Annotation)
# accessConditions(0..1)(Access)
# accessPermission(0..n)(Access)
# alternativeTitle(0..n)(Annotation)
# applyAccessTo(0..n)(Access)
# citationRequirement(0..1)(Access)
# confidentialityStatement(0..1)(Access)
# contactAgent(0..n)(Access)
# contributor(0..n)(Annotation)
# copyright(0..n)(Annotation)
# creator(0..n)(Annotation)
# date(0..n)(Annotation)
# depositRequirement(0..1)(Access)
# disclaimer(0..1)(Access)
# identifier(0..n)(Annotation)
# informationSource(0..n)(Annotation)
# language(0..n)(Annotation)
# overview(0..1)(Coverage)
# provenance(0..n)(Annotation)
# publisher(0..n)(Annotation)
# purpose(0..1)(Access)
# recordCreationDate(0..1)(Annotation)
# recordLastRevisionDate(0..1)(Annotation)
# relatedResource(0..n)(Annotation)
# restrictions(0..1)(Access)
# rights(0..n)(Annotation)
# subTitle(0..n)(Annotation)
# title(0..1)(Annotation)
# typeOfResource(0..n)(Annotation)
# validDates(0..1)(Access)
# versionIdentification(0..1)(Annotation)
# versionResponsibility(0..n)(Annotation)
#
# Nodes: ['Annotation', 'Access', 'Coverage']
#
# Edges: []
#
#
# View PhysicalDataDescriptionView
#
# Property List
# characterSet(0..1)(DataStore)
# recordCount(0..1)(DataStoreSummary)
# type(0..1)(DataStore)
#
# Nodes: ['DataStore', 'DataStoreSummary', 'DataStructure', 'DataPoint']
#
# Edges: [('DataStore', 'DataStructure')]
#
#
# View InstrumentView
#
# Property List
# analysisUnit(0..n)(Capture)
# analysisUnit(0..n)(RepresentedQuestion)
# associatedImage(0..1)(Instruction)
# commandCode(0..1)(InstrumentCode)
# constructSequence(0..1)(ProcessSequence)
# definition(0..1)(Concept)
# description(0..1)(ConceptualInstrument)
# descriptiveText(0..1)(ExternalMaterial)
# displayLabel(0..n)(Capture)
# displayLabel(0..n)(ConceptualInstrument)
# displayLabel(0..n)(ImplementedInstrument)
# displayLabel(0..n)(Instruction)
# estimatedResponseTimeInSeconds(0..1)(RepresentedQuestion)
# externalInstrumentLocation(0..n)(ImplementedInstrument)
# externalURLReference(0..n)(ExternalMaterial)
# externalURNReference(0..1)(ExternalMaterial)
# instantiatedQuestionName(0..1)(InstanceQuestion)
# instructionText(0..n)(Instruction)
# instructions(0..1)(Act)
# measurementName(0..n)(Capture)
# mimeType(0..1)(ExternalMaterial)
# name(0..n)(Concept)
# name(0..n)(ConceptualInstrument)
# name(0..n)(ImplementedInstrument)
# name(0..n)(Instruction)
# purpose(0..1)(Capture)
# purposeOfCode(0..1)(InstrumentCode)
# purposeOfStatement(0..1)(Statement)
# questionIntent(0..1)(RepresentedQuestion)
# questionText(0..n)(RepresentedQuestion)
# relationshipDescription(0..n)(ExternalMaterial)
# segment(0..n)(ExternalMaterial)
# source(0..1)(Capture)
# source(0..1)(RepresentedQuestion)
# statementText(0..n)(Statement)
# typeOfInstrument(0..1)(ImplementedInstrument)
# typeOfMaterial(0..1)(ExternalMaterial)
# typeOfSequence(0..n)(ProcessSequence)
# unitOfMeasurement(0..1)(RepresentedVariable)
# usage(0..1)(Capture)
# usage(0..1)(ConceptualInstrument)
# usage(0..n)(ImplementedInstrument)
#
# Nodes: ['ExternalMaterial', 'ConceptualInstrument', 'Act', 'Capture', 'SentinelValueDomain', 'Instruction', 'Statement', 'InstrumentComponent', 'Concept', 'InstanceQuestion', 'ProcessSequence', 'SubstantiveValueDomain', 'Observation', 'ImplementedInstrument', 'ResponseDomain', 'InstrumentCode', 'RepresentedVariable', 'RepresentedQuestion']
#
# Edges: [('ConceptualInstrument', 'ProcessSequence'), ('ConceptualInstrument', 'Capture'), ('Capture', 'ResponseDomain'), ('Capture', 'Instruction'), ('Capture', 'RepresentedVariable'), ('Capture', 'Concept'), ('InstrumentComponent', 'Instruction'), ('InstrumentComponent', 'Act'), ('InstanceQuestion', 'RepresentedQuestion'), ('Observation', 'InstrumentComponent'), ('ImplementedInstrument', 'ProcessSequence'), ('ImplementedInstrument', 'ConceptualInstrument'), ('ResponseDomain', 'SentinelValueDomain'), ('ResponseDomain', 'SubstantiveValueDomain'), ('RepresentedQuestion', 'RepresentedVariable'), ('RepresentedVariable', 'SubstantiveValueDomain')]
#
#
# View LogicalDataDescriptionView
#
# Property List
# descriptiveText(0..1)(ConceptualVariable)
# descriptiveText(0..1)(Population)
# descriptiveText(0..1)(UnitType)
# descriptiveText(0..1)(Universe)
# displayLabel(0..n)(ConceptualVariable)
# displayLabel(0..n)(Population)
# displayLabel(0..n)(SubstantiveConceptualDomain)
# displayLabel(0..n)(Unit)
# displayLabel(0..n)(UnitType)
# displayLabel(0..n)(Universe)
# displayLabel(0..n)(ValueDomain)
# isInclusive(0..1)(Universe)
# name(0..1)(UnitType)
# name(0..n)(ConceptualVariable)
# name(0..n)(Population)
# name(0..n)(Unit)
# name(0..n)(Universe)
# unitOfMeasurement(0..1)(RepresentedVariable)
# variableRole(0..1)(InstanceVariable)
#
# Nodes: ['SubstantiveValueDomain', 'Datum', 'Unit', 'Universe', 'CategorySet', 'ConceptualVariable', 'UnitType', 'DataPoint', 'SubstantiveConceptualDomain', 'SentinelValueDomain', 'CodeList', 'InstanceVariable', 'ValueDomain', 'RepresentedVariable', 'Population']
#
# Edges: [('SubstantiveValueDomain', 'SubstantiveConceptualDomain'), ('SubstantiveValueDomain', 'CodeList'), ('Datum', 'ValueDomain'), ('Datum', 'InstanceVariable'), ('Unit', 'UnitType'), ('SentinelValueDomain', 'CodeList'), ('ConceptualVariable', 'SubstantiveConceptualDomain'), ('ConceptualVariable', 'UnitType'), ('DataPoint', 'InstanceVariable'), ('DataPoint', 'Datum'), ('SubstantiveConceptualDomain', 'CategorySet'), ('Universe', 'Universe'), ('Universe', 'UnitType'), ('InstanceVariable', 'SentinelValueDomain'), ('InstanceVariable', 'ConceptualVariable'), ('InstanceVariable', 'RepresentedVariable'), ('InstanceVariable', 'Population'), ('RepresentedVariable', 'Universe'), ('RepresentedVariable', 'SubstantiveValueDomain'), ('RepresentedVariable', 'ConceptualVariable'), ('CodeList', 'SentinelValueDomain'), ('CodeList', 'CategorySet'), ('Population', 'Universe'), ('Population', 'Unit'), ('Population', 'Population')]
#
#
# View SimpleMethodology
#
# Property List
# displayLabel(0..n)(Unit)
# name(0..n)(Unit)
# overview(0..1)(Design)
# overview(0..1)(Process)
# overview(0..1)(Rationale)
# unitOfMeasurement(0..1)(RepresentedVariable)
#
# Nodes: ['Design', 'Process', 'Rationale', 'RepresentedVariable', 'Unit']
#
# Edges: [('Design', 'Rationale'), ('Process', 'Design')]
#
#
# View AgentsView
#
# Property List
# accessLocation(0..1)(Machine)
# address(0..n)(ContactInformation)
# cityPlaceLocal(0..1)(Address)
# contactAddress(0..1)(ElectronicMessageSystem)
# contactInformation(0..1)(Individual)
# contactInformation(0..1)(Organization)
# countryCode(0..1)(Address)
# ddiId(0..n)(Individual)
# ddiId(0..n)(Organization)
# effectiveDates(0..1)(ElectronicMessageSystem)
# effectiveDates(0..1)(Email)
# effectiveDates(0..1)(Telephone)
# effectiveDates(0..n)(Relation)
# effectivePeriod(0..1)(Address)
# electronicMessaging(0..n)(ContactInformation)
# email(0..n)(ContactInformation)
# function(0..n)(Machine)
# geographicPoint(0..1)(Address)
# individualName(1..n)(Individual)
# interface(0..n)(Machine)
# internetEmail(0..1)(Email)
# isPreferred(0..1)(Address)
# isPreferred(0..1)(ElectronicMessageSystem)
# isPreferred(0..1)(Email)
# isPreferred(0..1)(Telephone)
# line(0..n)(Address)
# locationName(0..1)(Address)
# machineName(0..1)(Machine)
# organizationName(1..n)(Organization)
# ownerOperatorContact(0..1)(Machine)
# postalCode(0..1)(Address)
# privacy(0..1)(Address)
# privacy(0..1)(ElectronicMessageSystem)
# privacy(0..1)(Email)
# privacy(0..1)(Relation)
# privacy(0..1)(Telephone)
# purpose(0..1)(Relation)
# regionalCoverage(0..1)(Address)
# stateProvince(0..1)(Address)
# telephone(0..n)(ContactInformation)
# telephoneNumber(0..1)(Telephone)
# timeZone(0..1)(Address)
# typeOfAddress(0..1)(Address)
# typeOfEmail(0..1)(Email)
# typeOfLocation(0..1)(Address)
# typeOfMachine(0..1)(Machine)
# typeOfRelationship(0..1)(Relation)
# typeOfService(0..1)(ElectronicMessageSystem)
# typeOfTelephone(0..1)(Telephone)
# website(0..n)(ContactInformation)
#
# Nodes: ['Email', 'Individual', 'ElectronicMessageSystem', 'Relation', 'Address', 'Organization', 'Telephone', 'ContactInformation', 'Machine']
#
# Edges: []
